# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 1.DATA

# %% [markdown]
# **1.1. Importing relevant libraries**

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

# %% [markdown]
# **1.2 Data Inspection And Analysis**
#
# To get a general sense of the structure and contents,we examine our datasets for preparation to ensure that the data is clean, well-understood, and properly prepared for creating accurate and reliable models.This is by checking basic information like the shape and consistency,looking out for missing, duplicates and NaN values,checking for duplicates and finally concatinating the datasets as necessary

# %% [markdown]
# **Step 1: Loading our Data**

# %%
#Step 1: Loading our Data

movies=pd.read_csv('Data/movies.csv')
ratings=pd.read_csv('Data/ratings.csv')
tags=pd.read_csv('Data/tags.csv')

# %% [markdown]
# **Step 2:Explore our 'movie' Dataset**

# %%
movies #print to inspect overall
# Out:
#       movieId                                      title  \
# 0           1                           Toy Story (1995)
# 1           2                             Jumanji (1995)
# 2           3                    Grumpier Old Men (1995)
# 3           4                   Waiting to Exhale (1995)
# 4           5         Father of the Bride Part II (1995)
# ...       ...                                        ...
# 9737   193581  Black Butler: Book of the Atlantic (2017)
# 9738   193583               No Game No Life: Zero (2017)
# 9739   193585                               Flint (2017)
# 9740   193587        Bungo Stray Dogs: Dead Apple (2018)
# 9741   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                            genres
# 0     Adventure|Animation|Children|Comedy|Fantasy
# 1                      Adventure|Children|Fantasy
# 2                                  Comedy|Romance
# 3                            Comedy|Drama|Romance
# ...

# %% [markdown]
# **'movies' dataset structure checks**

# %%
print(movies.info()) #To get info on data types and non-null counts
print(movies.describe()) #To check the summary statistics for numerical columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9742 entries, 0 to 9741
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   movieId  9742 non-null   int64
#  1   title    9742 non-null   object
#  2   genres   9742 non-null   object
# dtypes: int64(1), object(2)
# memory usage: 228.5+ KB
# None
#              movieId
# count    9742.000000
# mean    42200.353623
# std     52160.494854
# min         1.000000
# 25%      3248.250000
# 50%      7300.000000
# 75%     76232.000000
# max    193609.000000

# %% [markdown]
# **'Movies' Dataset quality checks**

# %%
print(movies.isnull().sum()) #To check for missing values
print(movies.duplicated().sum()) #To check for duplicate values
# Out:
# movieId    0
# title      0
# genres     0
# dtype: int64
# 0

# %% [markdown]
# **Summary Of Key Insights Of The 'movies' Dataset**
#
# * The Dataset contains information about 9742 *movies*(Rows), including their *movieIDs*, *titles* and *genres* (3 columns) and there data types.
# * The dataset has no missing or duplicate values

# %% [markdown]
# **Step 2:Explore our 'rating' Dataset**
#
# Here we use the same steps used to explore the 'movie' dataset

# %%
ratings #print to inspect overall
# Out:
#         userId  movieId  rating   timestamp
# 0            1        1     4.0   964982703
# 1            1        3     4.0   964981247
# 2            1        6     4.0   964982224
# 3            1       47     5.0   964983815
# 4            1       50     5.0   964982931
# ...        ...      ...     ...         ...
# 100831     610   166534     4.0  1493848402
# 100832     610   168248     5.0  1493850091
# 100833     610   168250     5.0  1494273047
# 100834     610   168252     5.0  1493846352
# 100835     610   170875     3.0  1493846415
#
# [100836 rows x 4 columns]

# %%
#Dataset structure checks

print(ratings.info()) #To get info on data types and non-null counts
print(ratings.describe()) #To check the summary statistics for numerical columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100836 entries, 0 to 100835
# Data columns (total 4 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   userId     100836 non-null  int64
#  1   movieId    100836 non-null  int64
#  2   rating     100836 non-null  float64
#  3   timestamp  100836 non-null  int64
# dtypes: float64(1), int64(3)
# memory usage: 3.1 MB
# None
#               userId        movieId         rating     timestamp
# count  100836.000000  100836.000000  100836.000000  1.008360e+05
# mean      326.127564   19435.295718       3.501557  1.205946e+09
# std       182.618491   35530.987199       1.042529  2.162610e+08
# min         1.000000       1.000000       0.500000  8.281246e+08
# 25%       177.000000    1199.000000       3.000000  1.019124e+09
# 50%       325.000000    2991.000000       3.500000  1.186087e+09
# 75%       477.000000    8122.000000       4.000000  1.435994e+09
# ...

# %%
#Dataset quality checks**

print(ratings.isnull().sum()) #To check for missing values
print(ratings.duplicated().sum()) #To check for duplicate values
# Out:
# userId       0
# movieId      0
# rating       0
# timestamp    0
# dtype: int64
# 0

# %% [markdown]
# **Summary of key insights of the 'ratigs' Dataset**
#
# * The Dataset contains information about 100836 user *ratings* (Rows), including *userIds*,*movieId*(Foreign key) rating and *timestamp* indicating when the rating was made(4 columns) and their data types
# * The dataset has no missing or duplicate values

# %% [markdown]
# **Step 3: Explore Our 'Tags' Dataset**

# %%
tags #print to inspect overall
# Out:
#       userId  movieId               tag   timestamp
# 0          2    60756             funny  1445714994
# 1          2    60756   Highly quotable  1445714996
# 2          2    60756      will ferrell  1445714992
# 3          2    89774      Boxing story  1445715207
# 4          2    89774               MMA  1445715200
# ...      ...      ...               ...         ...
# 3678     606     7382         for katie  1171234019
# 3679     606     7936           austere  1173392334
# 3680     610     3265            gun fu  1493843984
# 3681     610     3265  heroic bloodshed  1493843978
# 3682     610   168248  Heroic Bloodshed  1493844270
#
# [3683 rows x 4 columns]

# %%
#Dataset structure checks

print(tags.info()) #To get info on data types and non-null counts
print(tags.describe()) #To check the summary statistics for numerical columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3683 entries, 0 to 3682
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   userId     3683 non-null   int64
#  1   movieId    3683 non-null   int64
#  2   tag        3683 non-null   object
#  3   timestamp  3683 non-null   int64
# dtypes: int64(3), object(1)
# memory usage: 115.2+ KB
# None
#             userId        movieId     timestamp
# count  3683.000000    3683.000000  3.683000e+03
# mean    431.149335   27252.013576  1.320032e+09
# std     158.472553   43490.558803  1.721025e+08
# min       2.000000       1.000000  1.137179e+09
# 25%     424.000000    1262.500000  1.137521e+09
# 50%     474.000000    4454.000000  1.269833e+09
# 75%     477.000000   39263.000000  1.498457e+09
# max     610.000000  193565.000000  1.537099e+09

# %%
#Dataset quality checks**

print(tags.isnull().sum()) #To check for missing values
print(tags.duplicated().sum()) #To check for duplicate values
# Out:
# userId       0
# movieId      0
# tag          0
# timestamp    0
# dtype: int64
# 0

# %% [markdown]
# **Summary of key insights of the 'tags' Dataset**
#
# * The Dataset contains information about 3683 *tags* assigned by the user (Rows), including *userIds*,*movieId*(Foreign keys) *tags* and *timestamp* indicating when the tags were added(4 columns) and their data types
# * The dataset has no missing or duplicate values

# %% [markdown]
# **1.3 Merge Datasets**

# %%
# Merging ratings with movies
reco_df = pd.merge(ratings, movies, on='movieId', how='inner')
reco_df
# Out:
#         userId  movieId  rating   timestamp                             title  \
# 0            1        1     4.0   964982703                  Toy Story (1995)
# 1            5        1     4.0   847434962                  Toy Story (1995)
# 2            7        1     4.5  1106635946                  Toy Story (1995)
# 3           15        1     2.5  1510577970                  Toy Story (1995)
# 4           17        1     4.5  1305696483                  Toy Story (1995)
# ...        ...      ...     ...         ...                               ...
# 100831     610   160341     2.5  1479545749                  Bloodmoon (1997)
# 100832     610   160527     4.5  1479544998  Sympathy for the Underdog (1971)
# 100833     610   160836     3.0  1493844794                     Hazard (2005)
# 100834     610   163937     3.5  1493848789                Blair Witch (2016)
# 100835     610   163981     3.5  1493850155                         31 (2016)
#
# ...

# %%
#Dataset structure checks
print(reco_df.info()) #To get info on data types and non-null counts
print(reco_df.describe()) #To check the summary statistics for numerical columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100836 entries, 0 to 100835
# Data columns (total 6 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   userId     100836 non-null  int64
#  1   movieId    100836 non-null  int64
#  2   rating     100836 non-null  float64
#  3   timestamp  100836 non-null  int64
#  4   title      100836 non-null  object
#  5   genres     100836 non-null  object
# dtypes: float64(1), int64(3), object(2)
# memory usage: 5.4+ MB
# None
#               userId        movieId         rating     timestamp
# count  100836.000000  100836.000000  100836.000000  1.008360e+05
# mean      326.127564   19435.295718       3.501557  1.205946e+09
# std       182.618491   35530.987199       1.042529  2.162610e+08
# min         1.000000       1.000000       0.500000  8.281246e+08
# 25%       177.000000    1199.000000       3.000000  1.019124e+09
# 50%       325.000000    2991.000000       3.500000  1.186087e+09
# ...

# %%
#Dataset quality checks**

print(reco_df.isnull().sum()) #To check for missing values
print(reco_df.duplicated().sum()) #To check for duplicate values
# Out:
# userId       0
# movieId      0
# rating       0
# timestamp    0
# title        0
# genres       0
# dtype: int64
# 0
